# %%
fig, ax = plt.subplots(3,1,figsize=(8,8),sharex=True,constrained_layout=True)
regions = ['High Lat. Ocean','Land','Low Lat. Ocean']
for k in range(len(regions)):
  ax[0].plot(T_abr1[k,:].T, lw=2, c=brewer2_light(k), label = regions[k])
  ax[1].plot(T_exp1[k,:].T, lw=2, c=brewer2_light(k), label = regions[k])
  ax[2].plot(T_ove1[k,:].T, lw=2, c=brewer2_light(k), label = regions[k])

ax[0].legend()
ax[0].set_ylabel(r'Temperature [$^\circ$C]',fontsize=16)
ax[1].set_ylabel(r'Temperature [$^\circ$C]',fontsize=16)
ax[2].set_ylabel(r'Temperature [$^\circ$C]',fontsize=16)
ax[2].set_xlabel('Year',fontsize=16)
#ax[2].set_xticks([0, 18262.5, 36525, 54787.5, 73050, 91312.5])
#ax[2].set_xticklabels([0, 50, 100, 150, 200, 250])

#fig.savefig("Presentation/examples.png",dpi=500)

# %%
fig, ax = plt.subplots(5,2,figsize=(16,10),sharex=True,constrained_layout=True)
regions = ['High Lat. Ocean','Land','Low Lat. Ocean']
for k in range(len(regions)):
  ax[0,0].plot(F_imp1[k,:].T, lw=2, c=brewer2_light(k), label = regions[k])
  ax[0,1].plot(T_imp1[k,:].T, lw=2, c=brewer2_light(k), label = regions[k])

  ax[1,0].plot(F_stephold1[k,:].T, lw=2, c=brewer2_light(k), label = regions[k])
  ax[1,1].plot(T_stephold1[k,:].T, lw=2, c=brewer2_light(k), label = regions[k])

  ax[2,0].plot(F_multisine1[k,:].T, lw=2, c=brewer2_light(k), label = regions[k])
  ax[2,1].plot(T_multisine1[k,:].T, lw=2, c=brewer2_light(k), label = regions[k])

  ax[3,0].plot(F_white1[k,:].T, lw=2, c=brewer2_light(k), label = regions[k])
  ax[3,1].plot(T_white1[k,:].T, lw=2, c=brewer2_light(k), label = regions[k])

  ax[4,0].plot(F_composite1[k,:].T, lw=2, c=brewer2_light(k), label = regions[k])
  ax[4,1].plot(T_composite1[k,:].T, lw=2, c=brewer2_light(k), label = regions[k])

ax[0,0].legend()
ax[0,1].legend()
ax[0,0].set_title(r'Forcing [Wm$^{-2}$]',fontsize=20)
ax[0,1].set_title(r'Temperature [$^\circ$C]',fontsize=20)
#ax[4,0].set_xticks([0, 608.75, 1217.5, 1826.25, 2435, 3043.75])
#ax[4,0].set_xticklabels([0, 50, 100, 150, 200, 250])
#ax[4,1].set_xticks([0, 608.75, 1217.5, 1826.25, 2435, 3043.75])
#ax[4,0].set_xticklabels([0, 50, 100, 150, 200, 250])
ax[4,0].set_xlabel('Year',fontsize=20)
ax[4,1].set_xlabel('Year',fontsize=20)

#fig.savefig("Presentation/force_temp.png",dpi=500)

# %%
from matplotlib.lines import Line2D

T_R_comp1 = apply_response(F_stephold1, R_composite1)
T_R_comp3 = apply_response(F_stephold1, R_multisine1)
T_R_comp2 = apply_response(F_stephold1, R_exp1)

fig, ax = plt.subplots(2,1,figsize=(10,10),sharex=True,constrained_layout=True)
regions = ['High Lat. Ocean','Land','Low Lat. Ocean']
for k in range(len(regions)):
  ax[0].plot(T_stephold1[k,:].T, lw=2, c=brewer2_light(k), label = regions[k])
  ax[0].plot(T_R_comp1[k,:].T, lw=2, ls='-.', c=brewer2_light(k))

  ax[1].plot(T_stephold1[k,:].T, lw=2, c=brewer2_light(k), label = regions[k])
  ax[1].plot(T_R_comp3[k,:].T, lw=2, ls='-.', c=brewer2_light(k))

handles, labels = ax[0].get_legend_handles_labels()

extra = [
    Line2D([], [], color='gray', lw=2, linestyle='-',  label='Truth'),
    Line2D([], [], color='gray', lw=2, linestyle='-.', label='Emulator')
]

ax[0].legend(handles + extra, labels + [h.get_label() for h in extra])
ax[0].set_title('Response Function Trained w/ Composite Scenario',fontsize=20)
ax[0].set_ylabel(r'Temperature [$^\circ$C]',fontsize=20)
ax[1].set_title('Response Function Trained w/ Multisine Scenario',fontsize=20)
ax[1].set_ylabel(r'Temperature [$^\circ$C]',fontsize=20)
ax[-1].set_xlabel('Year',fontsize=20)

#fig.savefig("Presentation/response_compare2.png",dpi=500)

# %%
fig, ax = plt.subplots(2,1,figsize=(10,10),sharex=True,constrained_layout=True)
regions = ['High Lat. Ocean','Land','Low Lat. Ocean']
for k in range(len(regions)):
  ax[0].plot(R_composite1[0,k,:].T, lw=2, c=brewer2_light(k), label = regions[k])
  ax[1].plot(R_exp1[0,k,:].T, lw=2, c=brewer2_light(k), label = regions[k])
  #ax[0].plot(T_R_comp1[k,:].T, lw=2, ls='-.', c=brewer2_light(k))

  #ax[1].plot(T_stephold1[k,:].T, lw=2, c=brewer2_light(k), label = regions[k])
  #ax[1].plot(T_R_comp2[k,:].T, lw=2, ls='-.', c=brewer2_light(k))

ax[0].legend()
ax[0].set_title('High Latitude Ocean Response Trained w/ Composite Scenario',fontsize=20)
ax[0].set_ylabel(r'Response [$^\circ$C / (Wm$^2$)]',fontsize=20)
ax[1].set_title('High Latitude Ocean Response Trained w/ Exponential Scenario',fontsize=20)
ax[1].set_ylabel(r'Response [$^\circ$C / (Wm$^2$)]',fontsize=20)
ax[-1].set_xlabel('Year',fontsize=20)

#fig.savefig("Presentation/high_lat_response2.png",dpi=500)
